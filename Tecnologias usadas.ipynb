# %%
pip install builtwith
# Out:
# ...
#
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for builtwith: filename=builtwith-1.3.4-py3-none-any.whl size=36093 sha256=ca353e5ec51e349614137152578d52c4791b3bf220a3cc7c20e64f18dd7476b3
#   Stored in directory: c:\users\samsung\appdata\local\pip\cache\wheels\be\16\b5\70218da689a5a9d8cf951266eea6435c4efd4fff87d919cd1b
# Successfully built builtwith
# ...

# %%
pip install python-whois
# Out:
# ...
#      -------------------------------------- 104.2/104.2 kB 2.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import builtwith
import whois

# %%
builtwith.parse('https://consultadanfe.com/?gclid=EAIaIQobChMI2Lahqfj9-gIVAkVIAB3McQr_EAAYASAAEgI8XvD_BwE#')
# Out:
# {'cdn': ['CloudFlare'],
#  'font-scripts': ['Font Awesome'],
#  'tag-managers': ['Google Tag Manager'],
#  'javascript-frameworks': ['Modernizr', 'jQuery'],
#  'widgets': ['OWL Carousel'],
#  'photo-galleries': ['jQuery', 'OWL Carousel'],
#  'web-frameworks': ['Twitter Bootstrap']}

# %%
print(whois.whois('consultadanfe.com'))
# Out:
# {
#   "domain_name": "CONSULTADANFE.COM",
#   "registrar": "NameCheap, Inc.",
#   "registrar_url": "http://www.namecheap.com",
#   "reseller": null,
#   "whois_server": "whois.namecheap.com",
#   "referral_url": null,
#   "updated_date": "2023-08-23 18:08:55",
#   "creation_date": "2022-09-15 01:58:01",
#   "expiration_date": "2032-09-15 01:58:01",
#   "name_servers": [
#     "AISHA.NS.CLOUDFLARE.COM",
#     "BRAD.NS.CLOUDFLARE.COM"
#   ],
#   "status": "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#   "emails": "abuse@namecheap.com",
#   "dnssec": "unsigned",
#   "name": null,
#   "org": null,
#   "address": null,
#   "city": null,
#   "state": null,
#   "registrant_postal_code": null,
#   "country": null
# }
